# %%
from constant.whitelist_lst import LST, WEIGHTED_LST, AVG_LST, WeightedSymbol
from simulation.simulation import EpochSymbolData, EpochInfo, Simulation
from allocator.ema import EmaAllocator, EmaHistoricalData
from allocator.ma import MaAllocator, MaHistoricalData
from allocator.single import SingleAllocator
from allocator.equal import EqualAllocator
from allocator.ma import MaAllocator
from allocator.allocator import Allocator
from portfolio.portfolio import Portfolio
from helper.plot import Datapoint, PlotData, plots
from helper.historical import load_cached_historical_apys, load_historical_apys_until_epoch
from dataclasses import dataclass

@dataclass
class BacktestingGroup:
    name: str
    weighted_symbols: list[WeightedSymbol]
    allocator: Allocator

start_epoch = 610
end_epoch = 746
groups: list[BacktestingGroup] = [
    BacktestingGroup("MAXSOL_EMA(5)", LST, EmaAllocator()),
    BacktestingGroup("MAXSOL_EMA(5)_WEIGHTED", WEIGHTED_LST, EmaAllocator()),
    BacktestingGroup("MAXSOL_MA(5)", LST, MaAllocator()),
    BacktestingGroup("MAXSOL_MA(5)_WEIGHTED", WEIGHTED_LST, MaAllocator()),
    BacktestingGroup("AVG", AVG_LST, EqualAllocator()),
    # BacktestingGroup("JitoSOL", [WeightedSymbol("jitosol")], SingleAllocator()),
    # BacktestingGroup("mSOL", [WeightedSymbol("msol")], SingleAllocator()),
    # BacktestingGroup("INF", [WeightedSymbol("INF")], SingleAllocator()),
    # BacktestingGroup("JupSOL", [WeightedSymbol("jupsol")], SingleAllocator()),
    # BacktestingGroup("hSOL", [WeightedSymbol("hsol")], SingleAllocator()),
]

apy_plotdatas: list[PlotData] = []

for group in groups:

    # Prepare epoch symbol datas
    epoch_symbol_datas = []
    epoch_symbol_datas.append(EpochSymbolData("sol", [EpochInfo(epoch, 0.1, 1) for epoch in range(start_epoch, end_epoch + 1)]))
    for weighted_symbol in group.weighted_symbols:
        symbol = weighted_symbol.symbol
        historical_apys = load_cached_historical_apys(symbol)
        epoch_infos = [EpochInfo(x.epoch, x.apy, 1) for x in historical_apys]
        epoch_symbol_datas.append(EpochSymbolData(symbol, epoch_infos))

    # Prepare portfolio
    portfolio = Portfolio()
    portfolio.add("sol", 100)

    # Prepare simulation
    simulation = Simulation(portfolio, epoch_symbol_datas, start_epoch, end_epoch)

    apy_datapoints: list[Datapoint] = []
    for _ in simulation:
        epoch = simulation.get_current_epoch()

        # Prepare allocator data
        data = None
        if isinstance(group.allocator, EmaAllocator):
            data: list[EmaHistoricalData] = []
            for weighted_symbol in group.weighted_symbols:
                symbol = weighted_symbol.symbol
                historical_apys = load_historical_apys_until_epoch(symbol, epoch)
                data.append(EmaHistoricalData(symbol, historical_apys))
        elif isinstance(group.allocator, MaAllocator):
            data: list[MaHistoricalData] = []
            for weighted_symbol in group.weighted_symbols:
                symbol = weighted_symbol.symbol
                historical_apys = load_historical_apys_until_epoch(symbol, epoch)
                data.append(MaHistoricalData(symbol, historical_apys))
        elif isinstance(group.allocator, SingleAllocator):
            data = group.weighted_symbols[-1].symbol
        elif isinstance(group.allocator, EqualAllocator):
            data = group.weighted_symbols
        
        # Get allocations
        allocations = group.allocator.with_data(data).get_allocations(epoch)

        # Adjust allocations by symbol weights
        allocations = simulation.adjust_symbol_weights(group.weighted_symbols, allocations)

        # Rebalance
        simulation.rebalance(epoch, allocations)

        # ? Record datapoint

        # total token amount
        total_token_amount = portfolio.get_total_token_amount()
        apy_datapoints.append(Datapoint(epoch, total_token_amount))

    apy_plotdatas.append(PlotData(group.name, apy_datapoints))

plots("Cumulative Staked Token Amount", apy_plotdatas)

for d in apy_plotdatas:
    print(d)
# Out:
# PlotData(name='MAXSOL_EMA(5)', datapoints=[Datapoint(epoch=611, value=100.00053473260355, description=''), Datapoint(epoch=612, value=100.0010091793834, description=''), Datapoint(epoch=613, value=100.00152172142614, description=''), Datapoint(epoch=614, value=100.00209035559209, description=''), Datapoint(epoch=615, value=100.00264864510126, description=''), Datapoint(epoch=616, value=100.00322512149677, description=''), Datapoint(epoch=617, value=100.0038405211247, description=''), Datapoint(epoch=618, value=100.00441176989399, description=''), Datapoint(epoch=619, value=100.00501772613201, description=''), Datapoint(epoch=620, value=100.00563401463239, description=''), Datapoint(epoch=621, value=100.00622482034458, description=''), Datapoint(epoch=622, value=100.00681507967236, description=''), Datapoint(epoch=623, value=100.0074048251291, description=''), Datapoint(epoch=624, value=100.00797430107622, description=''), Datapoint(epoch=625, value=100.00857131372027, description=''), Datapoint(epoch=626, value=100.0091375071892, description=''), Datapoint(epoch=627, value=100.00974865924692, description=''), Datapoint(epoch=628, value=100.01042020396343, description=''), Datapoint(epoch=629, value=100.01103994489111, description=''), Datapoint(epoch=630, value=100.01176028408575, description=''), Datapoint(epoch=631, value=100.01240790535982, description=''), Datapoint(epoch=632, value=100.01313535117794, description=''), Datapoint(epoch=633, value=100.01379776723284, description=''), Datapoint(epoch=634, value=100.0144096825472, description=''), Datapoint(epoch=635, value=100.01499326430091, description=''), Datapoint(epoch=636, value=100.01553443185327, description=''), Datapoint(epoch=637, value=100.0162635632526, description=''), Datapoint(epoch=638, value=100.01685711693334, description=''), Datapoint(epoch=639, value=100.01747326880869, description=''), Datapoint(epoch=640, value=100.01806146124957, description=''), Datapoint(epoch=641, value=100.01858091147567, description=''), Datapoint(epoch=642, value=100.01920852215437, description=''), Datapoint(epoch=643, value=100.01985375693972, description=''), Datapoint(epoch=644, value=100.02055755725014, description=''), Datapoint(epoch=645, value=100.02127618419152, description=''), Datapoint(epoch=646, value=100.02181936718057, description=''), Datapoint(epoch=647, value=100.0224496095005, description=''), Datapoint(epoch=648, value=100.02298899995426, description=''), Datapoint(epoch=649, value=100.02361572371085, description=''), Datapoint(epoch=650, value=100.02430047162552, description=''), Datapoint(epoch=651, value=100.02486299176624, description=''), Datapoint(epoch=652, value=100.02554992950844, description=''), Datapoint(epoch=653, value=100.02590730732018, description=''), Datapoint(epoch=654, value=100.0265294195344, description=''), Datapoint(epoch=655, value=100.02711387680284, description=''), Datapoint(epoch=656, value=100.02767321549915, description=''), Datapoint(epoch=657, value=100.02831416734543, description=''), Datapoint(epoch=658, value=100.0289077472753, description=''), Datapoint(epoch=659, value=100.02952616022837, description=''), Datapoint(epoch=660, value=100.03011157770706, description=''), Datapoint(epoch=661, value=100.03059443064869, description=''), Datapoint(epoch=662, value=100.0310463993978, description=''), Datapoint(epoch=663, value=100.03154042958565, description=''), Datapoint(epoch=664, value=100.03202964399887, description=''), Datapoint(epoch=665, value=100.03252206618978, description=''), Datapoint(epoch=666, value=100.03301032786217, description=''), Datapoint(epoch=667, value=100.03351254396887, description=''), Datapoint(epoch=668, value=100.03397482049593, description=''), Datapoint(epoch=669, value=100.03447492096775, description=''), Datapoint(epoch=670, value=100.03493341863182, description=''), Datapoint(epoch=671, value=100.03538537839358, description=''), Datapoint(epoch=672, value=100.03585119723388, description=''), ...
# PlotData(name='MAXSOL_EMA(5)_WEIGHTED', datapoints=[Datapoint(epoch=611, value=100.00053651255426, description=''), Datapoint(epoch=612, value=100.00101623095256, description=''), Datapoint(epoch=613, value=100.00152172799332, description=''), Datapoint(epoch=614, value=100.00207114121628, description=''), Datapoint(epoch=615, value=100.00262724094604, description=''), Datapoint(epoch=616, value=100.00320343404127, description=''), Datapoint(epoch=617, value=100.00380089097112, description=''), Datapoint(epoch=618, value=100.00436948734166, description=''), Datapoint(epoch=619, value=100.00497498764018, description=''), Datapoint(epoch=620, value=100.00558810015687, description=''), Datapoint(epoch=621, value=100.00618093164329, description=''), Datapoint(epoch=622, value=100.00676815731376, description=''), Datapoint(epoch=623, value=100.00731641859471, description=''), Datapoint(epoch=624, value=100.00787377279417, description=''), Datapoint(epoch=625, value=100.00846910208527, description=''), Datapoint(epoch=626, value=100.00903329925816, description=''), Datapoint(epoch=627, value=100.00963201490353, description=''), Datapoint(epoch=628, value=100.01027340138906, description=''), Datapoint(epoch=629, value=100.01086594176707, description=''), Datapoint(epoch=630, value=100.0115563063256, description=''), Datapoint(epoch=631, value=100.01216608372197, description=''), Datapoint(epoch=632, value=100.01284688341417, description=''), Datapoint(epoch=633, value=100.01347693693276, description=''), Datapoint(epoch=634, value=100.0140631195092, description=''), Datapoint(epoch=635, value=100.01464149671213, description=''), Datapoint(epoch=636, value=100.0151857675299, description=''), Datapoint(epoch=637, value=100.01583634799228, description=''), Datapoint(epoch=638, value=100.01642777764673, description=''), Datapoint(epoch=639, value=100.01701641961905, description=''), Datapoint(epoch=640, value=100.01757209097376, description=''), Datapoint(epoch=641, value=100.01810718600217, description=''), Datapoint(epoch=642, value=100.01868762116524, description=''), Datapoint(epoch=643, value=100.01928153411839, description=''), Datapoint(epoch=644, value=100.01995363950387, description=''), Datapoint(epoch=645, value=100.02059938655844, description=''), Datapoint(epoch=646, value=100.02114207244108, description=''), Datapoint(epoch=647, value=100.02174788449805, description=''), Datapoint(epoch=648, value=100.02229576028539, description=''), Datapoint(epoch=649, value=100.02288638804788, description=''), Datapoint(epoch=650, value=100.0235243770626, description=''), Datapoint(epoch=651, value=100.02408129481732, description=''), Datapoint(epoch=652, value=100.02470940002922, description=''), Datapoint(epoch=653, value=100.02513396141589, description=''), Datapoint(epoch=654, value=100.02572288585654, description=''), Datapoint(epoch=655, value=100.0262979954278, description=''), Datapoint(epoch=656, value=100.02683192348536, description=''), Datapoint(epoch=657, value=100.02741436108394, description=''), Datapoint(epoch=658, value=100.0279603366007, description=''), Datapoint(epoch=659, value=100.02855338866168, description=''), Datapoint(epoch=660, value=100.02910137298908, description=''), Datapoint(epoch=661, value=100.0295843083278, description=''), Datapoint(epoch=662, value=100.03006151758758, description=''), Datapoint(epoch=663, value=100.03052638834063, description=''), Datapoint(epoch=664, value=100.03101495002566, description=''), Datapoint(epoch=665, value=100.03150415628515, description=''), Datapoint(epoch=666, value=100.03199118999687, description=''), Datapoint(epoch=667, value=100.0324969487142, description=''), Datapoint(epoch=668, value=100.03296421255429, description=''), Datapoint(epoch=669, value=100.03345340266652, description=''), Datapoint(epoch=670, value=100.03391653683975, description=''), Datapoint(epoch=671, value=100.03436375246636, description=''), Datapoint(epoch=672, value=100.03482757405303, descr ...
# PlotData(name='MAXSOL_MA(5)', datapoints=[Datapoint(epoch=611, value=100.00051996905195, description=''), Datapoint(epoch=612, value=100.00099441576177, description=''), Datapoint(epoch=613, value=100.0014996194091, description=''), Datapoint(epoch=614, value=100.00207180596608, description=''), Datapoint(epoch=615, value=100.00263740030546, description=''), Datapoint(epoch=616, value=100.00321607531913, description=''), Datapoint(epoch=617, value=100.00380839693499, description=''), Datapoint(epoch=618, value=100.00437964552077, description=''), Datapoint(epoch=619, value=100.00499115998643, description=''), Datapoint(epoch=620, value=100.00561417592455, description=''), Datapoint(epoch=621, value=100.00620498151955, description=''), Datapoint(epoch=622, value=100.00679524073027, description=''), Datapoint(epoch=623, value=100.00738916150347, description=''), Datapoint(epoch=624, value=100.00796025030073, description=''), Datapoint(epoch=625, value=100.00855467108934, description=''), Datapoint(epoch=626, value=100.00912086446405, description=''), Datapoint(epoch=627, value=100.00972693400215, description=''), Datapoint(epoch=628, value=100.01038834787117, description=''), Datapoint(epoch=629, value=100.0108606514688, description=''), Datapoint(epoch=630, value=100.01147469464134, description=''), Datapoint(epoch=631, value=100.01210789868838, description=''), Datapoint(epoch=632, value=100.01280690136393, description=''), Datapoint(epoch=633, value=100.01346931524341, description=''), Datapoint(epoch=634, value=100.01408122854819, description=''), Datapoint(epoch=635, value=100.01466480838538, description=''), Datapoint(epoch=636, value=100.0152059741605, description=''), Datapoint(epoch=637, value=100.0159351031653, description=''), Datapoint(epoch=638, value=100.01652865489677, description=''), Datapoint(epoch=639, value=100.01714480474865, description=''), Datapoint(epoch=640, value=100.01773299525786, description=''), Datapoint(epoch=641, value=100.01825244377801, description=''), Datapoint(epoch=642, value=100.01888005239559, description=''), Datapoint(epoch=643, value=100.01952528506195, description=''), Datapoint(epoch=644, value=100.02022908306103, description=''), Datapoint(epoch=645, value=100.02094770764236, description=''), Datapoint(epoch=646, value=100.02149088884758, description=''), Datapoint(epoch=647, value=100.02212112909777, description=''), Datapoint(epoch=648, value=100.02266051778012, description=''), Datapoint(epoch=649, value=100.02328723947849, description=''), Datapoint(epoch=650, value=100.02397198514441, description=''), Datapoint(epoch=651, value=100.02451914712846, description=''), Datapoint(epoch=652, value=100.02517442347329, description=''), Datapoint(epoch=653, value=100.0255106713801, description=''), Datapoint(epoch=654, value=100.02610728630125, description=''), Datapoint(epoch=655, value=100.02669174110315, description=''), Datapoint(epoch=656, value=100.02725107743892, description=''), Datapoint(epoch=657, value=100.02789202658025, description=''), Datapoint(epoch=658, value=100.02848560400507, description=''), Datapoint(epoch=659, value=100.02910201286453, description=''), Datapoint(epoch=660, value=100.02968742786089, description=''), Datapoint(epoch=661, value=100.03017027875514, description=''), Datapoint(epoch=662, value=100.03062224558781, description=''), Datapoint(epoch=663, value=100.03111747620005, description=''), Datapoint(epoch=664, value=100.03160549983508, description=''), Datapoint(epoch=665, value=100.03209791993808, description=''), Datapoint(epoch=666, value=100.0325861795402, description=''), Datapoint(epoch=667, value=100.03308839351743, description=''), Datapoint(epoch=668, value=100.03355066808439, description=''), Datapoint(epoch=669, value=100.03405076643574, description=''), Datapoint(epoch=670, value=100.03450926215577, description=''), Datapoint(epoch=671, value=100.03491541808734, description=''), Datapoint(epoch=672, value=100.03535570671468, description=' ...
# PlotData(name='MAXSOL_MA(5)_WEIGHTED', datapoints=[Datapoint(epoch=611, value=100.00051190663493, description=''), Datapoint(epoch=612, value=100.0009916249152, description=''), Datapoint(epoch=613, value=100.00148638927553, description=''), Datapoint(epoch=614, value=100.00203542801388, description=''), Datapoint(epoch=615, value=100.00260370243019, description=''), Datapoint(epoch=616, value=100.00317922559564, description=''), Datapoint(epoch=617, value=100.0037645345932, description=''), Datapoint(epoch=618, value=100.00433313075703, description=''), Datapoint(epoch=619, value=100.00495925052023, description=''), Datapoint(epoch=620, value=100.00559333315661, description=''), Datapoint(epoch=621, value=100.00618616467405, description=''), Datapoint(epoch=622, value=100.00677339037526, description=''), Datapoint(epoch=623, value=100.0073232501195, description=''), Datapoint(epoch=624, value=100.0078824859717, description=''), Datapoint(epoch=625, value=100.00846163469207, description=''